# %% [markdown]
# <a href="https://colab.research.google.com/github/Tawanss/BSC_DPDM23/blob/main/Frequent_Patterns_(Association_Rules).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/data minning/reduced_marketbasket.csv'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv(os.path.join(path,'/content/drive/MyDrive/data minning/reduced_marketbasket.csv'),encoding='latin-1')

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom
# ...                  ...        ...         ...             ...
# 541904  12/09/2011 12:50       0.85     12680.0          France
# 541905  12/09/2011 12:50       2.10     12680.0          France
# 541906  12/09/2011 12:50       4.15     12680.0          France
# 541907  12/09/2011 12:50       4.15     12680.0          France
# 541908  12/09/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# Quiz: ข้อมูลมาจากกี่ประเทศ

# %%
len(set(data['Country']))
# Out:
# 38

# %%
data['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %% [markdown]
# # แปลง data ให้อยู่ในรูปแบบ Transaction data ด้วย *groupby.apply(list)*

# %%
data.groupby('InvoiceNo')['StockCode'].apply(list)
# Out:
# InvoiceNo
# 536365     [85123A, 71053, 84406B, 84029G, 84029E, 22752,...
# 536366                                        [22633, 22632]
# 536367     [84879, 22745, 22748, 22749, 22310, 84969, 226...
# 536368                          [22960, 22913, 22912, 22914]
# 536369                                               [21756]
#                                  ...
# C581484                                              [23843]
# C581490                                       [22178, 23144]
# C581499                                                  [M]
# C581568                                              [21258]
# C581569                                       [84978, 20979]
# Name: StockCode, Length: 25900, dtype: object

# %%
transactions = data.groupby('InvoiceNo')['StockCode'].apply(list)

# %% [markdown]
# ## Association Rules

# %%
# !pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5954 sha256=8c21bba51c8fa3a25c7d661701320da0cb758c7b9813451750f21b3ddecb15d3
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
from apyori import apriori

# %%
apriori(transactions,min_support = 0.5)
# Out:
# <generator object apriori at 0x7a33de7f7ca0>

# %%
list(apriori(transactions,min_support = 0.065))
# Out:
# [RelationRecord(items=frozenset({'22423'}), support=0.08386100386100385, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22423'}), confidence=0.08386100386100385, lift=1.0)]),
#  RelationRecord(items=frozenset({'47566'}), support=0.06586872586872587, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'47566'}), confidence=0.06586872586872587, lift=1.0)]),
#  RelationRecord(items=frozenset({'85099B'}), support=0.08243243243243244, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85099B'}), confidence=0.08243243243243244, lift=1.0)]),
#  RelationRecord(items=frozenset({'85123A'}), support=0.08671814671814672, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85123A'}), confidence=0.08671814671814672, lift=1.0)])]

# %%
frequentItemsets = list(apriori(transactions,min_support = 0.065))
frequentItemsets
# Out:
# [RelationRecord(items=frozenset({'22423'}), support=0.08386100386100385, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22423'}), confidence=0.08386100386100385, lift=1.0)]),
#  RelationRecord(items=frozenset({'47566'}), support=0.06586872586872587, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'47566'}), confidence=0.06586872586872587, lift=1.0)]),
#  RelationRecord(items=frozenset({'85099B'}), support=0.08243243243243244, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85099B'}), confidence=0.08243243243243244, lift=1.0)]),
#  RelationRecord(items=frozenset({'85123A'}), support=0.08671814671814672, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85123A'}), confidence=0.08671814671814672, lift=1.0)])]

# %%
len(frequentItemsets)
# Out:
# 4

# %%
frequentItemsets[0]
# Out:
# RelationRecord(items=frozenset({'22423'}), support=0.08386100386100385, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22423'}), confidence=0.08386100386100385, lift=1.0)])

# %%
frequentItemsets[0][0]
# Out:
# frozenset({'22423'})

# %%
dir(frequentItemsets[0][0])
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'copy',
#  'difference',
#  'intersection',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'symmetric_difference',
#  'union']

# %%
frequentItemsets[0][0].__len__()
# Out:
# 1

# %%
min_sup = 0.03

frequentItemsets = list(apriori(transactions,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'85099B', '22386'}), support=0.03216216216216216, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85099B', '22386'}), confidence=0.03216216216216216, lift=1.0), OrderedStatistic(items_base=frozenset({'22386'}), items_add=frozenset({'85099B'}), confidence=0.6766856214459789, lift=8.20897311262335), OrderedStatistic(items_base=frozenset({'85099B'}), items_add=frozenset({'22386'}), confidence=0.39016393442622943, lift=8.20897311262335)])
# yes
# RelationRecord(items=frozenset({'22697', '22699'}), support=0.03027027027027027, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22697', '22699'}), confidence=0.03027027027027027, lift=1.0), OrderedStatistic(items_base=frozenset({'22697'}), items_add=frozenset({'22699'}), confidence=0.7417218543046358, lift=17.1523178807947), OrderedStatistic(items_base=frozenset({'22699'}), items_add=frozenset({'22697'}), confidence=0.7, lift=17.1523178807947)])

# %% [markdown]
# RelationRecord(items=frozenset({'22386', '85099B'}),
#
# support=0.03216216216216216,
#
# ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22386', '85099B'}), confidence=0.03216216216216216, lift=1.0),
#
# OrderedStatistic(items_base=frozenset({'22386'}), items_add=frozenset({'85099B'}), confidence=0.6766856214459789, lift=8.20897311262335),
#
# OrderedStatistic(items_base=frozenset({'85099B'}), items_add=frozenset({'22386'}), confidence=0.39016393442622943, lift=8.20897311262335)])

# %%
set(data[(data['StockCode']=='22386') | (data['StockCode']=='85099B') | (data['StockCode']=='22699') | (data['StockCode']=='22697') ]['Description'])
# Out:
# {'GREEN REGENCY TEACUP AND SAUCER',
#  'JUMBO BAG PINK POLKADOT',
#  'JUMBO BAG RED RETROSPOT',
#  'ROSES REGENCY TEACUP AND SAUCER '}

# %% [markdown]
# Quiz <br>
# stock code 22386 and 85099B คือสินค้าอะไร

# %%
set(data[(data['StockCode']=='22386')]['Description'])
# Out:
# {'JUMBO BAG PINK POLKADOT'}

# %%
set(data[(data['StockCode']=='85099B')]['Description'])
# Out:
# {'JUMBO BAG RED RETROSPOT'}

# %% [markdown]
# RelationRecord(items=frozenset({'22699', '22697'}), support=0.03027027027027027,
#
# ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22699', '22697'}), confidence=0.03027027027027027, lift=1.0),
# <br>
# <br>
#
# OrderedStatistic(items_base=frozenset({'22697'}), items_add=frozenset({'22699'}), confidence=0.7417218543046358, lift=17.1523178807947),
#
# OrderedStatistic(items_base=frozenset({'22699'}), items_add=frozenset({'22697'}), confidence=0.7, lift=17.1523178807947)])

# %%
set(data[(data['StockCode']=='22699') | (data['StockCode']=='22697')]['InvoiceNo'])
# Out:
# {'552694',
#  '539442',
#  '538071',
#  '558030',
#  '570465',
#  '566624',
#  '577594',
#  '552804',
#  '549524',
#  'C548485',
#  '558565',
#  '575185',
#  'C558434',
#  '547493',
#  'C541822',
#  'C556644',
#  '544089',
#  '557642',
#  '566602',
#  '552247',
#  '578065',
#  '550474',
#  '554030',
#  '556243',
#  '547846',
#  'C543633',
#  '562534',
#  '554113',
#  '545377',
#  '553578',
#  '545320',
#  '553607',
#  '562607',
#  '570720',
#  '546752',
#  '565155',
#  '557605',
#  '542349',
#  '550307',
#  '559930',
#  '551717',
#  '575138',
#  '551286',
#  '542632',
#  '554643',
#  '566788',
#  '541932',
#  '568048',
#  '550953',
#  '541132',
#  'C538124',
#  '556095',
#  '550500',
#  '550210',
#  '565919',
#  'C546125',
#  '537754',
#  '564820',
#  '579445',
#  '545912',
#  '557621',
#  '543532',
#  '547387',
#  '559491',
#  '562353',
#  '572758',
#  '544778',
#  '565424',
#  '566617',
#  '558119',
#  '575206',
#  '546688',
#  '554040',
#  '576672',
#  '542629',
#  '552642',
#  '553013',
#  '546212',
#  '551340',
#  '561798',
#  'C556880',
#  '558240',
#  '547063',
#  '548734',
#  '558372',
#  '570700',
#  '549999',
#  '540465',
#  '554382',
#  'C569114',
#  '566477',
#  '566577',
#  '550899',
#  '566985',
#  '559497',
#  '543546',
#  '547042',
#  '558066',
#  '537335',
#  '566976',
#  '557645',
#  '563613',
#  '579508',
#  '537645',
#  '539437',
#  '557481',
#  '567922',
#  '555488',
#  '575490',
#  '579503',
#  '552149',
#  '560580',
#  '573580',
#  '569246',
#  '543909',
#  '566720',
#  '540352',
#  '573388',
#  '557500',
#  '549120',
#  '554110',
#  '555695',
#  'C565848',
#  '578844',
#  '571797',
#  '553462',
#  '548893',
#  '558873',
#  '574298',
#  '545014',
#  '580612',
#  '580673',
#  '577078',
#  '564199',
#  '571433',
#  '567663',
#  '551062',
#  '540364',
#  '563909',
#  '550613',
#  '545474',
#  '569367',
#  '563353',
#  '558923',
#  '550638',
#  '564065',
#  '544920',
#  '542719',
#  '557560',
#  '573822',
#  '565231',
#  '544421',
#  '564092',
#  '565120',
#  'C566084',
#  '541280',
#  '545759',
#  '560590',
#  '544206',
#  '562608',
#  '537534',
#  '549997',
#  '559112',
#  '556917',
#  '554036',
#  '543973',
#  '547938',
#  '541999',
#  '547841',
#  '553612',
#  '565289',
#  '564221',
#  '537042',
#  '546760',
#  'C559667',
#  '557117',
#  '566094',
#  '576388',
#  '550519',
#  '550499',
#  '555150',
#  '548158',
#  '557968',
#  '553035',
#  '548003',
#  '546545',
#  '547788',
#  '571257',
#  '544305',
#  '557145',
#  '551775',
#  '552710',
#  '545036',
#  '561891',
#  '542647',
#  '539594',
#  '541870',
#  '553566',
#  '575484',
#  '576644',
#  '537642',
#  '567639',
#  '562713',
#  '567670',
#  '577358',
#  '559357',
#  '573553',
#  '578067',
#  '546136',
#  '554013',
#  '568567',
#  '550968',
#  '561926',
#  'C555254',
#  '566170',
#  '558103',
#  '564817',
#  '548210',
#  '558116',
#  '580667',
#  '558774',
#  '581345',
#  '544660',
#  '537385',
#  '552614',
#  '552336',
#  '536856',
#  '566988',
#  '562770',
#  '554139',
#  '564758',
#  'C545456',
#  '565779',
#  '537435',
#  '573576',
#  '551960',
#  '553575',
#  '568369',
#  '557616',
#  '578044',
#  '575930',
#  '545568',
#  '546367',
#  '563910',
#  '547096',
#  '564975',
#  '555109',
#  '559942',
#  '551171',
#  '550437',
#  '544394',
#  '543201',
#  '555574',
#  'C562921',
#  '564974',
#  '574368',
#  '558073',
#  '547360',
#  '548192',
#  '567631',
#  '561933',
#  '550125',
#  '572229',
#  '541495',
#  '559055',
#  '573778',
#  '552687',
#  '545215',
#  '578347',
#  '543099',
#  '580526',
#  '567656',
#  '570514',
#  '575846',
#  '560246',
#  '571034',
#  '546315',
#  '565117',
#  '576202',
#  '559510',
#  '553162',
#  '552662',
#  '562427',
#  '575515',
#  '550987',
#  '565214',
#  '566326',
#  '543045',
#  '567528',
#  '559489',
#  '543754',
#  '564972',
#  '545078',
#  '579102',
#  '542221',
#  '540418',
#  '571550',
#  '578149',
#  '559878',
#  '547828',
#  '552514',
#  '544055',
#  '541008',
#  '554326',
#  '549222',
#  '553002',
#  '554958',
#  '551825',
#  '544201',
#  '555848',
#  '568792',
#  '550025',
#  '564754',
#  '581170',
#  '538524',
#  'C578144',
#  '548673',
#  '543013',
#  '560826',
#  '554813',
#  '545690',
#  '567157',
#  '556206',
#  '544668',
#  '548212',
#  '556434',
#  '564723',
#  '578273',
#  '563193',
#  '545719',
#  '537738',
#  '571713',
#  '578314',
#  '579572',
#  '560906',
#  '544684',
#  '539436',
#  '573070',
#  '574700',
#  '577618',
#  '580774',
#  '564552',
#  'C562119',
#  '548983',
#  '551005',
#  '569544',
#  '548373',
#  '562374',
#  '561355',
#  '550215',
#  '554026',
#  '554974',
#  '539450',
#  '563505',
#  '546096',
#  '537237',
#  '545667',
#  '554098',
#  '544887',
#  '562264',
#  '551944',
#  '538851',
#  '566395',
#  '560451',
#  '544913',
#  '578817',
#  '543055',
#  '552533',
#  '566257',
#  '542717',
#  '569545',
#  '559295',
#  '562717',
#  '565150',
#  '543487',
#  '572897',
#  '556821',
#  '579297',
#  '577316',
#  '552563',
#  '552678',
#  '558262',
#  '550314',
#  '571546',
#  '566981',
#  '575947',
#  '554028',
#  '543626',
#  '555477',
#  '543451',
#  '554039',
#  '566603',
#  '578344',
#  '580173',
#  '564755',
#  '538951',
#  '554798',
#  '566236',
#  '555510',
#  'C545724',
#  '546915',
#  '567378',
#  '558035',
#  '562033',
#  '550205',
#  '566597',
#  '564300',
#  '581023',
#  '553542',
#  '570428',
#  '562843',
#  '545176',
#  '538880',
#  '561714',
#  '544837',
#  '537666',
#  '540026',
#  '550201',
#  '571061',
#  '562219',
#  '554124',
#  '578949',
#  '544081',
#  '543629',
#  '570227',
#  '562955',
#  '573330',
#  '558904',
#  '570488',
#  '562157',
#  '580053',
#  '569918',
#  '552816',
#  '548409',
#  '557782',
#  '559173',
#  '560780',
#  '561455',
#  '545063',
#  '541530',
#  '552867',
#  '547826',
#  '577355',
#  '546896',
#  '537830',
#  '559557',
#  'C545828',
#  '551860',
#  '558348',
#  '544339',
#  '558540',
#  '538371',
#  '547386',
#  '575176',
#  '549927',
#  '543277',
#  '543370',
#  '554337',
#  '564172',
#  '561125',
#  '553146',
#  '562420',
#  '569374',
#  '567140',
#  '568654',
#  'C546865',
#  '551160',
#  '560357',
#  '539468',
#  'C564212',
#  '555278',
#  '536862',
#  '564301',
#  'C549840',
#  '565838',
#  '544768',
#  '555499',
#  '577258',
#  '567886',
#  '554921',
#  '568988',
#  'C555358',
#  '568553',
#  '568333',
#  '572035',
#  '546498',
#  '553901',
#  '544779',
#  '549587',
#  '545340',
#  '580983',
#  '537240',
#  '578031',
#  '554158',
#  '565784',
#  '547248',
#  'C542263',
#  '572553',
#  '551057',
#  '551014',
#  '553671',
#  '541811',
#  '555870',
#  '551088',
#  '573083',
#  '554557',
#  '558681',
#  '552302',
#  '569137',
#  '568781',
#  '536876',
#  '555925',
#  '550183',
#  '557034',
#  '564091',
#  '570834',
#  '580665',
#  '546888',
#  'C552016',
#  '561820',
#  '555275',
#  '549124',
#  '544186',
#  '574893',
#  '548648',
#  '553891',
#  '563906',
#  '574561',
#  '549750',
#  '538862',
#  '560777',
#  '564714',
#  '546884',
#  '553387',
#  '574088',
#  '576899',
#  '539465',
#  '569577',
#  '581006',
#  '552323',
#  '564184',
#  '541110',
#  '567793',
#  '562202',
#  '562573',
#  '566583',
#  '545696',
#  '544812',
#  '562849',
#  '544596',
#  '570650',
#  '575866',
#  '569415',
#  '555647',
#  '577298',
#  '568346',
#  '568651',
#  '555722',
#  '552843',
#  '575946',
#  '554560',
#  '556812',
#  '540915',
#  '566255',
#  '573585',
#  '556813',
#  '558777',
#  'C558312',
#  '541969',
#  '553946',
#  '572028',
#  '572274',
#  'C577388',
#  '541497',
#  '541866',
#  '550471',
#  '571377',
#  '536524',
#  'C539071',
#  '550958',
#  '551339',
#  '556205',
#  '578936',
#  '548333',
#  '546306',
#  '562273',
#  '559906',
#  '550989',
#  '566559',
#  '545214',
#  '549425',
#  '562711',
#  '549056',
#  'C556793',
#  '558089',
#  '560209',
#  '547399',
#  '562102',
#  'C564854',
#  '548768',
#  'C566758',
#  '540664',
#  'C550648',
#  '551173',
#  '542691',
#  '553535',
#  '552259',
#  '543530',
#  '542115',
#  '558526',
#  '553543',
#  '541576',
#  '561698',
#  '550468',
#  '539738',
#  '538883',
#  '565519',
#  'C562375',
#  '559639',
#  'C567358',
#  '567324',
#  '543486',
#  '558770',
#  '574739',
#  '562222',
#  '556073',
#  '546562',
#  '553369',
#  '543923',
#  '572540',
#  '578827',
#  '538177',
#  'C555598',
#  '552857',
#  '576339',
#  '540464',
#  '545464',
#  '552308',
#  '576181',
#  '538660',
#  '545411',
#  '541424',
#  '544338',
#  '567873',
#  '571560',
#  '550265',
#  '537378',
#  '557735',
#  '543732',
#  '552449',
#  '561070',
#  '557350',
#  '572092',
#  '565151',
#  '564432',
#  'C537853',
#  '553385',
#  '556284',
#  '565781',
#  '561633',
#  '544314',
#  '550986',
#  '576616',
#  '549909',
#  '555106',
#  '552663',
#  'C559949',
#  '563477',
#  '549296',
#  '543107',
#  '554310',
#  '558068',
#  'C545449',
#  '537313',
#  '536623',
#  '566790',
#  '576246',
#  '547712',
#  '577518',
#  '537643',
#  '548260',
#  '545333',
#  '536865',
#  '572212',
#  '553210',
#  '560225',
#  '560291',
#  '558475',
#  'C558255',
#  '536946',
#  '540539',
#  'C555253',
#  '580501',
#  '544657',
#  '555743',
#  '551174',
#  '541421',
#  '573892',
#  '548559',
#  '563561',
#  '554483',
#  '550458',
#  '550333',
#  '572751',
#  '548163',
#  '568908',
#  '543246',
#  '575620',
#  '555486',
#  '563076',
#  '554372',
#  '548714',
#  '544833',
#  '546927',
#  'C556268',
#  '557493',
#  '568057',
#  '554714',
#  '555147',
#  '544067',
#  '537434',
#  '564057',
#  '553661',
#  '561217',
#  '556082',
#  '546683',
#  '542102',
#  '553718',
#  '544205',
#  '562377',
#  '545216',
#  '546892',
#  '567341',
#  '556826',
#  '554694',
#  '539735',
#  '567368',
#  '575939',
#  '542881',
#  '563384',
#  '549192',
#  '553899',
#  '545445',
#  '559938',
#  '574856',
#  '579093',
#  '570187',
#  '577597',
#  '551953',
#  '549592',
#  '565234',
#  '543565',
#  '548808',
#  '571714',
#  '547385',
#  '555630',
#  '537688',
#  '563951',
#  'C561232',
#  '547936',
#  '539587',
#  'C574548',
#  '552270',
#  '542389',
#  '562282',
#  '542664',
#  '540777',
#  '560634',
#  '569568',
#  '547967',
#  '568310',
#  'C551511',
#  '544749',
#  '549595',
#  '557494',
#  '575931',
#  '563614',
#  '565726',
#  '579267',
#  '551352',
#  '555276',
#  '543106',
#  '553191',
#  'C543837',
#  '543097',
#  '579471',
#  '542583',
#  '536592',
#  '542729',
#  '549360',
#  '571931',
#  '561236',
#  '540839',
#  '551997',
#  '552231',
#  '547206',
#  '577512',
#  '541423',
#  '561394',
#  '577076',
#  '542619',
#  '546660',
#  '570713',
#  '581472',
#  '544824',
#  '544208',
#  '546891',
#  '544677',
#  '557259',
#  '537022',
#  '565840',
#  '541219',
#  '576837',
#  '568199',
#  '545020',
#  '552540',
#  '547547',
#  '546837',
#  'C551465',
#  '576690',
#  '541130',
#  '568065',
#  '575477',
#  '539434',
#  '561637',
#  '560398',
#  '567336',
#  '556259',
#  '563922',
#  '548663',
#  '561209',
#  '580729',
#  '558862',
#  '579539',
#  '578994',
#  '581433',
#  '571241',
#  '570597',
#  '539708',
#  '559525',
#  '536627',
#  '542527',
#  '554842',
#  '579012',
#  '552975',
#  '577691',
#  '541220',
#  '549525',
#  '555400',
#  '548860',
#  '572550',
#  '549730',
#  '573125',
#  '546113',
#  '566600',
#  '537396',
#  '539635',
#  '548191',
#  'C545438',
#  '574076',
#  '563023',
#  '563169',
#  '576381',
#  '556953',
#  '577500',
#  '544565',
#  '551564',
#  '550438',
#  '551550',
#  '568193',
#  '552557',
#  '540992',
#  '544888',
#  '571219',
#  '543019',
#  '558683',
#  '543022',
#  '550915',
#  '550302',
#  '551334',
#  'C564964',
#  '570872',
#  '560976',
#  '553870',
#  '553489',
#  '568060',
#  '537179',
#  '565849',
#  '577400',
#  '539736',
#  '559124',
#  '552664',
#  '554054',
#  '543602',
#  '556016',
#  '571446',
#  '549261',
#  '572082',
#  '574328',
#  '550251',
#  '562166',
#  'C572410',
#  '570824',
#  '543116',
#  'C537834',
#  '581122',
#  '544940',
#  '540259',
#  '542344',
#  '566581',
#  '566871',
#  '542999',
#  '546158',
#  '556415',
#  '539739',
#  '559817',
#  '556256',
#  '559052',
#  '574707',
#  '541695',
#  '551657',
#  '581498',
#  '548159',
#  'C548355',
#  '548974',
#  '567280',
#  '564835',
#  '553202',
#  '560504',
#  '540372',
#  '547830',
#  '579777',
#  '549305',
#  '563442',
#  '558702',
#  '546314',
#  '569888',
#  '538148',
#  '564825',
#  '561651',
#  '560473',
#  '580367',
#  'C553479',
#  'C560560',
#  '570459',
#  '545945',
#  '561051',
#  '576255',
#  '578331',
#  '546980',
#  '577498',
#  '581219',
#  '539742',
#  '561631',
#  '537254',
#  'C554330',
#  '565748',
#  '542622',
#  '547249',
#  '545543',
#  '577319',
#  '556636',
#  '574334',
#  '565841',
#  '579927',
#  '580730',
#  '540848',
#  '552734',
#  '577531',
#  '542600',
#  '557973',
#  '556459',
#  '549435',
#  'C545525',
#  '544928',
#  '560604',
#  'C544665',
#  '551994',
#  '571508',
#  '556264',
#  '568955',
#  '566537',
#  '543036',
#  '539217',
#  '544664',
#  '563549',
#  '575703',
#  'C556635',
#  '548919',
#  '575739',
#  '559553',
#  '577039',
#  '578943',
#  '538370',
#  '546669',
#  '544681',
#  '571745',
#  '545681',
#  'C550664',
#  '565223',
#  ...}

# %%
data[data['InvoiceNo']=='562950']
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 297488    562950     22752        SET 7 BABUSHKA NESTING BOXES         2
# 297489    562950     22755     SMALL PURPLE BABUSHKA NOTEBOOK         12
# 297490    562950     22753     SMALL YELLOW BABUSHKA NOTEBOOK         12
# 297491    562950     22754        SMALL RED BABUSHKA NOTEBOOK         12
# 297492    562950     22757        LARGE RED BABUSHKA NOTEBOOK         12
# 297493    562950     22758    LARGE PURPLE BABUSHKA NOTEBOOK          12
# 297494    562950     22756     LARGE YELLOW BABUSHKA NOTEBOOK         12
# 297495    562950     23310             BUBBLEGUM RING ASSORTED        36
# 297496    562950     23280  FOLDING BUTTERFLY MIRROR HOT PINK         12
# 297497    562950     22383              LUNCH BAG SUKI DESIGN         10
# 297498    562950     22492             MINI PAINT SET VINTAGE         36
# 297499    562950     71459      HANGING JAM JAR T-LIGHT HOLDER        12
# 297500    562950     84945  MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 297501    562950     21175         GIN + TONIC DIET METAL SIGN        12
# 297502    562950     23164                  REGENCY CAKE SLICE         4
# 297503    562950     23245          SET OF 3 REGENCY CAKE TINS         4
# 297504    562950     23171            REGENCY TEA PLATE GREEN         12
# 297505    562950     22697     GREEN REGENCY TEACUP AND SAUCER         6
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 297488  08/11/2011 09:56       8.50     15608.0  United Kingdom
# 297489  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297490  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297491  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297492  08/11/2011 09:56       1.25     15608.0  United Kingdom
# 297493  08/11/2011 09:56       1.25     15608.0  United Kingdom
# 297494  08/11/2011 09:56       1.25     15608.0  United Kingdom
# 297495  08/11/2011 09:56       0.42     15608.0  United Kingdom
# 297496  08/11/2011 09:56       0.83     15608.0  United Kingdom
# 297497  08/11/2011 09:56       1.65     15608.0  United Kingdom
# 297498  08/11/2011 09:56       0.65     15608.0  United Kingdom
# 297499  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297500  08/11/2011 09:56       0.85     15608.0  United Kingdom
# 297501  08/11/2011 09:56       2.55     15608.0  United Kingdom
# 297502  08/11/2011 09:56       4.95     15608.0  United Kingdom
# 297503  08/11/2011 09:56       4.95     15608.0  United Kingdom
# 297504  08/11/2011 09:56       1.65     15608.0  United Kingdom
# 297505  08/11/2011 09:56       2.95     15608.0  United Kingdom

# %% [markdown]
# #HW 1 หา Frequent Item Set และ Association Rules
# * ของช่วงเวลา Christmas & New Year (1 Dec - 31 Dec)
# * ของประเทศในทวีป Europe
# * ของช่วงเวลา ตรุษจีน ในทวีป Asia  (15 Jan - 15 Feb)
# * ของช่วงเวลา  Christmas & New Year ในทวีป Europe (1 Dec - 31 Dec)
# * ของวันวาเลนไทน์
# * โดยจัดกลุ่มตามประเทศ + เดือน

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/01/2010 08:26       2.55     17850.0  United Kingdom
# 1  12/01/2010 08:26       3.39     17850.0  United Kingdom
# 2  12/01/2010 08:26       2.75     17850.0  United Kingdom
# 3  12/01/2010 08:26       3.39     17850.0  United Kingdom
# 4  12/01/2010 08:26       3.39     17850.0  United Kingdom

# %%
data_HW = data.copy()
data_HW
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom
# ...                  ...        ...         ...             ...
# 541904  12/09/2011 12:50       0.85     12680.0          France
# 541905  12/09/2011 12:50       2.10     12680.0          France
# 541906  12/09/2011 12:50       4.15     12680.0          France
# 541907  12/09/2011 12:50       4.15     12680.0          France
# 541908  12/09/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
# Given data
countries = ['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
             'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
             'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
             'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
             'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
             'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
             'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
             'European Community', 'Malta', 'RSA']

# Fictional mapping of countries to continents (replace with accurate data)
continent_mapping = {
    'United Kingdom': 'Europe',
    'France': 'Europe',
    'Australia': 'Oceania',
    'Netherlands': 'Europe',
    'Germany': 'Europe',
    'Norway': 'Europe',
    'EIRE': 'Europe',
    'Switzerland': 'Europe',
    'Spain': 'Europe',
    'Poland': 'Europe',
    'Portugal': 'Europe',
    'Italy': 'Europe',
    'Belgium': 'Europe',
    'Lithuania': 'Europe',
    'Japan': 'Asia',
    'Iceland': 'Europe',
    'Channel Islands': 'Europe',
    'Denmark': 'Europe',
    'Cyprus': 'Europe',
    'Sweden': 'Europe',
    'Austria': 'Europe',
    'Israel': 'Asia',
    'Finland': 'Europe',
    'Bahrain': 'Asia',
    'Greece': 'Europe',
    'Hong Kong': 'Asia',
    'Singapore': 'Asia',
    'Lebanon': 'Asia',
    'United Arab Emirates': 'Asia',
    'Saudi Arabia': 'Asia',
    'Czech Republic': 'Europe',
    'Canada': 'North America',
    'Unspecified': 'Unknown',
    'Brazil': 'South America',
    'USA': 'North America',
    'European Community': 'Europe',
    'Malta': 'Europe',
    'RSA': 'Africa'
}

# Create a DataFrame
data_continent = {'Country': countries, 'Continent': [continent_mapping.get(country, 'Unknown') for country in countries]}
df_continent = pd.DataFrame(data_continent)

# Display the DataFrame
df_continent.head()
# Out:
#           Country Continent
# 0  United Kingdom    Europe
# 1          France    Europe
# 2       Australia   Oceania
# 3     Netherlands    Europe
# 4         Germany    Europe

# %%
df_continent
# Out:
#                  Country      Continent
# 0         United Kingdom         Europe
# 1                 France         Europe
# 2              Australia        Oceania
# 3            Netherlands         Europe
# 4                Germany         Europe
# 5                 Norway         Europe
# 6                   EIRE         Europe
# 7            Switzerland         Europe
# 8                  Spain         Europe
# 9                 Poland         Europe
# 10              Portugal         Europe
# 11                 Italy         Europe
# 12               Belgium         Europe
# 13             Lithuania         Europe
# 14                 Japan           Asia
# 15               Iceland         Europe
# 16       Channel Islands         Europe
# 17               Denmark         Europe
# 18                Cyprus         Europe
# 19                Sweden         Europe
# 20               Austria         Europe
# 21                Israel           Asia
# 22               Finland         Europe
# 23               Bahrain           Asia
# 24                Greece         Europe
# 25             Hong Kong           Asia
# 26             Singapore           Asia
# 27               Lebanon           Asia
# 28  United Arab Emirates           Asia
# 29          Saudi Arabia           Asia
# 30        Czech Republic         Europe
# 31                Canada  North America
# 32           Unspecified        Unknown
# 33                Brazil  South America
# 34                   USA  North America
# 35    European Community         Europe
# 36                 Malta         Europe
# 37                   RSA         Africa

# %%
df_continent['Continent'].value_counts()
# Out:
# Europe           24
# Asia              8
# North America     2
# Oceania           1
# Unknown           1
# South America     1
# Africa            1
# Name: Continent, dtype: int64

# %%
df_continent['Continent'].count()
# Out:
# 38

# %% [markdown]
# # เช็คประเทศ

# %%
df_continent.sort_values(by = 'Continent')
# Out:
#                  Country      Continent
# 37                   RSA         Africa
# 14                 Japan           Asia
# 29          Saudi Arabia           Asia
# 28  United Arab Emirates           Asia
# 27               Lebanon           Asia
# 26             Singapore           Asia
# 25             Hong Kong           Asia
# 23               Bahrain           Asia
# 21                Israel           Asia
# 19                Sweden         Europe
# 20               Austria         Europe
# 24                Greece         Europe
# 36                 Malta         Europe
# 30        Czech Republic         Europe
# 35    European Community         Europe
# 22               Finland         Europe
# 17               Denmark         Europe
# 0         United Kingdom         Europe
# 15               Iceland         Europe
# 1                 France         Europe
# 3            Netherlands         Europe
# 4                Germany         Europe
# 16       Channel Islands         Europe
# 6                   EIRE         Europe
# 7            Switzerland         Europe
# 5                 Norway         Europe
# 9                 Poland         Europe
# 10              Portugal         Europe
# 11                 Italy         Europe
# 12               Belgium         Europe
# 13             Lithuania         Europe
# 8                  Spain         Europe
# 18                Cyprus         Europe
# 31                Canada  North America
# 34                   USA  North America
# 2              Australia        Oceania
# 33                Brazil  South America
# 32           Unspecified        Unknown

# %%
data_HW_continent = data_HW.merge(df_continent, how ='left', left_on='Country',right_on='Country')
print(data_HW_continent.shape)
data_HW_continent.head()
# Out:
# (541909, 9)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country Continent
# 0  12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1  12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2  12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3  12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4  12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe

# %%
data_HW_continent
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
# [541909 rows x 9 columns]

# %%
data_HW_continent_date = data_HW_continent.copy()

# %%
data_HW_continent_date['date_time'] = pd.to_datetime(data_HW_continent_date['InvoiceDate'])

# %%
data_HW_continent_date.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0  12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1  12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2  12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3  12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4  12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
#
#             date_time
# 0 2010-12-01 08:26:00
# 1 2010-12-01 08:26:00
# 2 2010-12-01 08:26:00
# 3 2010-12-01 08:26:00
# 4 2010-12-01 08:26:00

# %%
data_HW_continent_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 541909 entries, 0 to 541908
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
#  8   Continent    541909 non-null  object
#  9   date_time    541909 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 45.5+ MB

# %% [markdown]
# # Data Prep

# %%
data.isnull().any()
# Out:
# InvoiceNo      False
# StockCode      False
# Description     True
# Quantity       False
# InvoiceDate    False
# UnitPrice      False
# CustomerID      True
# Country        False
# dtype: bool

# %%
data[data['Description'].isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity       InvoiceDate  UnitPrice  \
# 622       536414     22139         NaN        56  12/01/2010 11:52        0.0
# 1970      536545     21134         NaN         1  12/01/2010 14:32        0.0
# 1971      536546     22145         NaN         1  12/01/2010 14:33        0.0
# 1972      536547     37509         NaN         1  12/01/2010 14:33        0.0
# 1987      536549    85226A         NaN         1  12/01/2010 14:34        0.0
# ...          ...       ...         ...       ...               ...        ...
# 535322    581199     84581         NaN        -2  12/07/2011 18:26        0.0
# 535326    581203     23406         NaN        15  12/07/2011 18:31        0.0
# 535332    581209     21620         NaN         6  12/07/2011 18:35        0.0
# 536981    581234     72817         NaN        27  12/08/2011 10:33        0.0
# 538554    581408     85175         NaN        20  12/08/2011 14:06        0.0
#
#         CustomerID         Country
# 622            NaN  United Kingdom
# 1970           NaN  United Kingdom
# 1971           NaN  United Kingdom
# 1972           NaN  United Kingdom
# 1987           NaN  United Kingdom
# ...            ...             ...
# 535322         NaN  United Kingdom
# 535326         NaN  United Kingdom
# 535332         NaN  United Kingdom
# 536981         NaN  United Kingdom
# 538554         NaN  United Kingdom
#
# [1454 rows x 8 columns]

# %%
len(set(data[data['Description'].isnull()]['StockCode']))
# Out:
# 960

# %%
data[data['StockCode'] == '22139']
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 106       536381     22139  RETROSPOT TEA SET CERAMIC 11 PC         23
# 622       536414     22139                               NaN        56
# 6392      536942     22139                            amazon        15
# 6885      536982     22139  RETROSPOT TEA SET CERAMIC 11 PC         10
# 7203      537011     22139                               NaN        -5
# ...          ...       ...                               ...       ...
# 538411    581405     22139  RETROSPOT TEA SET CERAMIC 11 PC          1
# 539531    581439     22139  RETROSPOT TEA SET CERAMIC 11 PC          1
# 540441    581486     22139  RETROSPOT TEA SET CERAMIC 11 PC          6
# 541387    581498     22139  RETROSPOT TEA SET CERAMIC 11 PC          2
# 541726    581570     22139  RETROSPOT TEA SET CERAMIC 11 PC          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 106     12/01/2010 09:41       4.25     15311.0  United Kingdom
# 622     12/01/2010 11:52       0.00         NaN  United Kingdom
# 6392    12/03/2010 12:08       0.00         NaN  United Kingdom
# 6885    12/03/2010 14:27      11.02         NaN  United Kingdom
# 7203    12/03/2010 15:38       0.00         NaN  United Kingdom
# ...                  ...        ...         ...             ...
# 538411  12/08/2011 13:50       4.95     13521.0  United Kingdom
# 539531  12/08/2011 16:30      10.79         NaN  United Kingdom
# 540441  12/09/2011 09:38       4.95     17001.0  United Kingdom
# 541387  12/09/2011 10:26      10.79         NaN  United Kingdom
# 541726  12/09/2011 11:59       4.95     12662.0         Germany
#
# [993 rows x 8 columns]

# %%
data[data['UnitPrice'] <0 ]
# Out:
#        InvoiceNo StockCode      Description  Quantity       InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1  08/12/2011 14:51
# 299984   A563187         B  Adjust bad debt         1  08/12/2011 14:52
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
data.iloc[299980:299986]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 299980    563184    82494L        WOODEN FRAME ANTIQUE WHITE          4
# 299981    563184     82482  WOODEN PICTURE FRAME WHITE FINISH         4
# 299982   A563185         B                    Adjust bad debt         1
# 299983   A563186         B                    Adjust bad debt         1
# 299984   A563187         B                    Adjust bad debt         1
# 299985    563188     79160      HEART SHAPE WIRELESS DOORBELL        48
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 299980  08/12/2011 14:50       2.95     17516.0  United Kingdom
# 299981  08/12/2011 14:50       2.55     17516.0  United Kingdom
# 299982  08/12/2011 14:50   11062.06         NaN  United Kingdom
# 299983  08/12/2011 14:51  -11062.06         NaN  United Kingdom
# 299984  08/12/2011 14:52  -11062.06         NaN  United Kingdom
# 299985  08/12/2011 15:00       1.69     15606.0  United Kingdom

# %%
data[data['StockCode'] == 'B']
# Out:
#        InvoiceNo StockCode      Description  Quantity       InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1  08/12/2011 14:50
# 299983   A563186         B  Adjust bad debt         1  08/12/2011 14:51
# 299984   A563187         B  Adjust bad debt         1  08/12/2011 14:52
#
#         UnitPrice  CustomerID         Country
# 299982   11062.06         NaN  United Kingdom
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
data[data['InvoiceNo'] == 'A563187' ]
# Out:
#        InvoiceNo StockCode      Description  Quantity       InvoiceDate  \
# 299984   A563187         B  Adjust bad debt         1  08/12/2011 14:52
#
#         UnitPrice  CustomerID         Country
# 299984  -11062.06         NaN  United Kingdom

# %%
data[data['Description'].isnull()]['StockCode'].value_counts()
# Out:
# 35965     10
# 23084     10
# 22084      9
# 22451      6
# 22501      5
#           ..
# 16169P     1
# 84846A     1
# 82545A     1
# 84251F     1
# 85175      1
# Name: StockCode, Length: 960, dtype: int64

# %%
data[data['Quantity']<0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 141     12/01/2010 09:41      27.50     14527.0  United Kingdom
# 154     12/01/2010 09:49       4.65     15311.0  United Kingdom
# 235     12/01/2010 10:24       1.65     17548.0  United Kingdom
# 236     12/01/2010 10:24       0.29     17548.0  United Kingdom
# 237     12/01/2010 10:24       0.29     17548.0  United Kingdom
# ...                  ...        ...         ...             ...
# 540449  12/09/2011 09:57       0.83     14397.0  United Kingdom
# 541541  12/09/2011 10:28     224.69     15498.0  United Kingdom
# 541715  12/09/2011 11:57      10.95     15311.0  United Kingdom
# 541716  12/09/2011 11:58       1.25     17315.0  United Kingdom
# 541717  12/09/2011 11:58       1.25     17315.0  United Kingdom
#
# [10624 rows x 8 columns]

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
data_positive = data[(data['Quantity']>=0) & (data['UnitPrice'] >=0) ]
data_positive
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom
# ...                  ...        ...         ...             ...
# 541904  12/09/2011 12:50       0.85     12680.0          France
# 541905  12/09/2011 12:50       2.10     12680.0          France
# 541906  12/09/2011 12:50       4.15     12680.0          France
# 541907  12/09/2011 12:50       4.15     12680.0          France
# 541908  12/09/2011 12:50       4.95     12680.0          France
#
# [531283 rows x 8 columns]

# %%
data_positive.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  531283.000000  531283.000000  397924.000000
# mean       10.655299       3.898954   15294.315171
# std       156.830617      35.876279    1713.169877
# min         1.000000       0.000000   12346.000000
# 25%         1.000000       1.250000   13969.000000
# 50%         3.000000       2.080000   15159.000000
# 75%        10.000000       4.130000   16795.000000
# max     80995.000000   13541.330000   18287.000000

# %%
data_positive[data_positive['UnitPrice'] == 0]
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 622       536414     22139                           NaN        56
# 1970      536545     21134                           NaN         1
# 1971      536546     22145                           NaN         1
# 1972      536547     37509                           NaN         1
# 1987      536549    85226A                           NaN         1
# ...          ...       ...                           ...       ...
# 535334    581211     22142                         check        14
# 536981    581234     72817                           NaN        27
# 538504    581406    46000M  POLYESTER FILLER PAD 45x45cm       240
# 538505    581406    46000S  POLYESTER FILLER PAD 40x40cm       300
# 538554    581408     85175                           NaN        20
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 622     12/01/2010 11:52        0.0         NaN  United Kingdom
# 1970    12/01/2010 14:32        0.0         NaN  United Kingdom
# 1971    12/01/2010 14:33        0.0         NaN  United Kingdom
# 1972    12/01/2010 14:33        0.0         NaN  United Kingdom
# 1987    12/01/2010 14:34        0.0         NaN  United Kingdom
# ...                  ...        ...         ...             ...
# 535334  12/07/2011 18:36        0.0         NaN  United Kingdom
# 536981  12/08/2011 10:33        0.0         NaN  United Kingdom
# 538504  12/08/2011 13:58        0.0         NaN  United Kingdom
# 538505  12/08/2011 13:58        0.0         NaN  United Kingdom
# 538554  12/08/2011 14:06        0.0         NaN  United Kingdom
#
# [1179 rows x 8 columns]

# %%
data[(data['InvoiceNo'] == 'C581490') | (data['InvoiceNo'] == 'C581499')]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 540448   C581490     22178  VICTORIAN GLASS HANGING T-LIGHT       -12
# 540449   C581490     23144  ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                           Manual        -1
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 540448  12/09/2011 09:57       1.95     14397.0  United Kingdom
# 540449  12/09/2011 09:57       0.83     14397.0  United Kingdom
# 541541  12/09/2011 10:28     224.69     15498.0  United Kingdom

# %%
data[(data['CustomerID'] == 14397)]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 182820    552575     22178    VICTORIAN GLASS HANGING T-LIGHT        24
# 182821    552575     23144    ZINC T-LIGHT HOLDER STARS SMALL        12
# 182822    552575     20846  ZINC HEART LATTICE T-LIGHT HOLDER        12
# 182823    552575     82484  WOOD BLACK BOARD ANT WHITE FINISH         2
# 182824    552575     84946       ANTIQUE SILVER T-LIGHT GLASS        12
# ...          ...       ...                                ...       ...
# 533101    581011     22478           BIRDHOUSE GARDEN MARKER         20
# 533102    581011     20846  ZINC HEART LATTICE T-LIGHT HOLDER        24
# 533103    581011     22600      CHRISTMAS RETROSPOT STAR WOOD        12
# 540448   C581490     22178    VICTORIAN GLASS HANGING T-LIGHT       -12
# 540449   C581490     23144    ZINC T-LIGHT HOLDER STARS SMALL       -11
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 182820  05/10/2011 12:25       1.25     14397.0  United Kingdom
# 182821  05/10/2011 12:25       0.83     14397.0  United Kingdom
# 182822  05/10/2011 12:25       1.25     14397.0  United Kingdom
# 182823  05/10/2011 12:25       7.95     14397.0  United Kingdom
# 182824  05/10/2011 12:25       1.25     14397.0  United Kingdom
# ...                  ...        ...         ...             ...
# 533101  12/07/2011 09:22       1.25     14397.0  United Kingdom
# 533102  12/07/2011 09:22       1.25     14397.0  United Kingdom
# 533103  12/07/2011 09:22       0.85     14397.0  United Kingdom
# 540448  12/09/2011 09:57       1.95     14397.0  United Kingdom
# 540449  12/09/2011 09:57       0.83     14397.0  United Kingdom
#
# [95 rows x 8 columns]

# %% [markdown]
# ## ตัดรายการที่มีค่า Quantity เป็น ลบ และ UnitPrice < 0

# %%
data_HW_continent_date_clean1 = data_HW_continent_date[(data_HW_continent_date['Quantity']>=0) & (data_HW_continent_date['UnitPrice'] >=0) ]
data_HW_continent_date_clean1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
#                  date_time
# 0      2010-12-01 08:26:00
# 1      2010-12-01 08:26:00
# 2      2010-12-01 08:26:00
# 3      2010-12-01 08:26:00
# 4      2010-12-01 08:26:00
# ...                    ...
# 541904 2011-12-09 12:50:00
# 541905 2011-12-09 12:50:00
# 541906 2011-12-09 12:50:00
# 541907 2011-12-09 12:50:00
# 541908 2011-12-09 12:50:00
#
# [531283 rows x 10 columns]

# %% [markdown]
# # Adding Time Period

# %%
data_dadate = data_HW_continent_date_clean1.copy()

# %%
data_dadate
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
#                  date_time
# 0      2010-12-01 08:26:00
# 1      2010-12-01 08:26:00
# 2      2010-12-01 08:26:00
# 3      2010-12-01 08:26:00
# 4      2010-12-01 08:26:00
# ...                    ...
# 541904 2011-12-09 12:50:00
# 541905 2011-12-09 12:50:00
# 541906 2011-12-09 12:50:00
# 541907 2011-12-09 12:50:00
# 541908 2011-12-09 12:50:00
#
# [531283 rows x 10 columns]

# %% [markdown]
# ## test period time

# %% [markdown]
# ## Christmas and New Year

# %%
# Christmas_period
# Define the date period
start_month = 12  # December
start_day = 1
end_month = 12    # December
end_day = 31

# Check if each date is within the specified period every year
data_dadate['Xmask_NY_Period'] = (
    (data_dadate['date_time'].dt.month > start_month) |
    ((data_dadate['date_time'].dt.month == start_month) & (data_dadate['date_time'].dt.day >= start_day))
) & (
    (data_dadate['date_time'].dt.month < end_month) |
    ((data_dadate['date_time'].dt.month == end_month) & (data_dadate['date_time'].dt.day <= end_day))
)

data_dadate
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
#                  date_time  Xmask_NY_Period
# 0      2010-12-01 08:26:00             True
# 1      2010-12-01 08:26:00             True
# 2      2010-12-01 08:26:00             True
# 3      2010-12-01 08:26:00             True
# 4      2010-12-01 08:26:00             True
# ...                    ...              ...
# 541904 2011-12-09 12:50:00             True
# 541905 2011-12-09 12:50:00             True
# 541906 2011-12-09 12:50:00             True
# 541907 2011-12-09 12:50:00             True
# 541908 2011-12-09 12:50:00             True
#
# [531283 rows x 11 columns]

# %% [markdown]
# ## Chinese New Year

# %%
# Chinese New Year
# Define the date period
start_month = 1  # January
start_day = 15
end_month = 2    # Febuary
end_day = 15

# Check if each date is within the specified period every year
data_dadate['CNY_Period'] = (
    (data_dadate['date_time'].dt.month > start_month) |
    ((data_dadate['date_time'].dt.month == start_month) & (data_dadate['date_time'].dt.day >= start_day))
) & (
    (data_dadate['date_time'].dt.month < end_month) |
    ((data_dadate['date_time'].dt.month == end_month) & (data_dadate['date_time'].dt.day <= end_day))
)

data_dadate
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
#                  date_time  Xmask_NY_Period  CNY_Period
# 0      2010-12-01 08:26:00             True       False
# 1      2010-12-01 08:26:00             True       False
# 2      2010-12-01 08:26:00             True       False
# 3      2010-12-01 08:26:00             True       False
# 4      2010-12-01 08:26:00             True       False
# ...                    ...              ...         ...
# 541904 2011-12-09 12:50:00             True       False
# 541905 2011-12-09 12:50:00             True       False
# 541906 2011-12-09 12:50:00             True       False
# 541907 2011-12-09 12:50:00             True       False
# 541908 2011-12-09 12:50:00             True       False
#
# [531283 rows x 12 columns]

# %%
data_dadate[data_dadate['CNY_Period']]
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 58345    541238     21115                ROSE CARAVAN DOORSTOP         1
# 58346    541238     22957  SET 3 PAPER VINTAGE CHICK PAPER EGG         1
# 58347    541238     22758     LARGE PURPLE BABUSHKA NOTEBOOK           1
# 58348    541238     20750             RED RETROSPOT MINI CASES         2
# 58349    541238     22722    SET OF 6 SPICE TINS PANTRY DESIGN         1
# ...         ...       ...                                  ...       ...
# 91285    544089    15056N            EDWARDIAN PARASOL NATURAL         3
# 91286    544089    84406B       CREAM CUPID HEARTS COAT HANGER         3
# 91287    544089     22087             PAPER BUNTING WHITE LACE         3
# 91288    544089     22631             CIRCUS PARADE LUNCH BOX          2
# 91289    544089     22630                 DOLLY GIRL LUNCH BOX         2
#
#            InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 58345  1/16/2011 10:42       6.75     16746.0  United Kingdom    Europe
# 58346  1/16/2011 10:42       2.95     16746.0  United Kingdom    Europe
# 58347  1/16/2011 10:42       1.25     16746.0  United Kingdom    Europe
# 58348  1/16/2011 10:42       7.95     16746.0  United Kingdom    Europe
# 58349  1/16/2011 10:42       3.95     16746.0  United Kingdom    Europe
# ...                ...        ...         ...             ...       ...
# 91285  2/15/2011 17:51       5.95         NaN  United Kingdom    Europe
# 91286  2/15/2011 17:51       4.15         NaN  United Kingdom    Europe
# 91287  2/15/2011 17:51       2.95         NaN  United Kingdom    Europe
# 91288  2/15/2011 17:51       1.95         NaN  United Kingdom    Europe
# 91289  2/15/2011 17:51       1.95         NaN  United Kingdom    Europe
#
#                 date_time  Xmask_NY_Period  CNY_Period
# 58345 2011-01-16 10:42:00            False        True
# 58346 2011-01-16 10:42:00            False        True
# 58347 2011-01-16 10:42:00            False        True
# 58348 2011-01-16 10:42:00            False        True
# 58349 2011-01-16 10:42:00            False        True
# ...                   ...              ...         ...
# 91285 2011-02-15 17:51:00            False        True
# 91286 2011-02-15 17:51:00            False        True
# 91287 2011-02-15 17:51:00            False        True
# 91288 2011-02-15 17:51:00            False        True
# 91289 2011-02-15 17:51:00            False        True
#
# [32125 rows x 12 columns]

# %% [markdown]
# ##Valentine's Day

# %%
# Valentine's Day
# Define the date period
start_month = 2  # January
start_day = 14
end_month = 2    # Febuary
end_day = 14

# Check if each date is within the specified period every year
data_dadate['V_Period'] = (
    (data_dadate['date_time'].dt.month > start_month) |
    ((data_dadate['date_time'].dt.month == start_month) & (data_dadate['date_time'].dt.day >= start_day))
) & (
    (data_dadate['date_time'].dt.month < end_month) |
    ((data_dadate['date_time'].dt.month == end_month) & (data_dadate['date_time'].dt.day <= end_day))
)

data_dadate
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
#                  date_time  Xmask_NY_Period  CNY_Period  V_Period
# 0      2010-12-01 08:26:00             True       False     False
# 1      2010-12-01 08:26:00             True       False     False
# 2      2010-12-01 08:26:00             True       False     False
# 3      2010-12-01 08:26:00             True       False     False
# 4      2010-12-01 08:26:00             True       False     False
# ...                    ...              ...         ...       ...
# 541904 2011-12-09 12:50:00             True       False     False
# 541905 2011-12-09 12:50:00             True       False     False
# 541906 2011-12-09 12:50:00             True       False     False
# 541907 2011-12-09 12:50:00             True       False     False
# 541908 2011-12-09 12:50:00             True       False     False
#
# [531283 rows x 13 columns]

# %%
data_dadate[data_dadate['V_Period']]
# Out:
#       InvoiceNo StockCode                         Description  Quantity  \
# 88847    543821     22926      IVORY GIANT GARDEN THERMOMETER         2
# 88848    543821     22928     YELLOW GIANT GARDEN THERMOMETER         2
# 88849    543821     22925       BLUE GIANT GARDEN THERMOMETER         2
# 88850    543821     85175               CACTI T-LIGHT CANDLES        16
# 88851    543821     22456     NATURAL SLATE CHALKBOARD LARGE          3
# ...         ...       ...                                 ...       ...
# 89949    543979     22196        SMALL HEART MEASURING SPOONS         1
# 89950    543979     21889              WOODEN BOX OF DOMINOES         1
# 89951    543979     85176          SEWING SUSAN 21 NEEDLE SET         1
# 89952    543979     37446  MINI CAKE STAND WITH HANGING CAKES         1
# 89953    543979     21657     MILK BOTTLE WITH GLASS STOPPER          1
#
#            InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 88847   2/14/2011 9:24       5.95     17667.0  United Kingdom    Europe
# 88848   2/14/2011 9:24       5.95     17667.0  United Kingdom    Europe
# 88849   2/14/2011 9:24       5.95     17667.0  United Kingdom    Europe
# 88850   2/14/2011 9:24       0.42     17667.0  United Kingdom    Europe
# 88851   2/14/2011 9:24       4.95     17667.0  United Kingdom    Europe
# ...                ...        ...         ...             ...       ...
# 89949  2/14/2011 15:43       0.85     14606.0  United Kingdom    Europe
# 89950  2/14/2011 15:43       1.25     14606.0  United Kingdom    Europe
# 89951  2/14/2011 15:43       0.85     14606.0  United Kingdom    Europe
# 89952  2/14/2011 15:43       1.45     14606.0  United Kingdom    Europe
# 89953  2/14/2011 15:43       6.95     14606.0  United Kingdom    Europe
#
#                 date_time  Xmask_NY_Period  CNY_Period  V_Period
# 88847 2011-02-14 09:24:00            False        True      True
# 88848 2011-02-14 09:24:00            False        True      True
# 88849 2011-02-14 09:24:00            False        True      True
# 88850 2011-02-14 09:24:00            False        True      True
# 88851 2011-02-14 09:24:00            False        True      True
# ...                   ...              ...         ...       ...
# 89949 2011-02-14 15:43:00            False        True      True
# 89950 2011-02-14 15:43:00            False        True      True
# 89951 2011-02-14 15:43:00            False        True      True
# 89952 2011-02-14 15:43:00            False        True      True
# 89953 2011-02-14 15:43:00            False        True      True
#
# [1087 rows x 13 columns]

# %% [markdown]
# #HW1 Q1

# %%
data_xmas = data_dadate[data_dadate['Xmask_NY_Period']]

# %%
transactions_xmas = data_xmas.groupby('InvoiceNo')['StockCode'].apply(list)

# %%
min_sup = 0.04

frequentItemsets = list(apriori(transactions_xmas,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'22086', '22910'}), support=0.058752025931928686, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22086', '22910'}), confidence=0.058752025931928686, lift=1.0), OrderedStatistic(items_base=frozenset({'22086'}), items_add=frozenset({'22910'}), confidence=0.5197132616487455, lift=5.938205230319926), OrderedStatistic(items_base=frozenset({'22910'}), items_add=frozenset({'22086'}), confidence=0.6712962962962963, lift=5.938205230319926)])
# yes
# RelationRecord(items=frozenset({'22111', '22112'}), support=0.04051863857374392, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22111', '22112'}), confidence=0.04051863857374392, lift=1.0), OrderedStatistic(items_base=frozenset({'22111'}), items_add=frozenset({'22112'}), confidence=0.45871559633027525, lift=5.265628333688927), OrderedStatistic(items_base=frozenset({'22112'}), items_add=frozenset({'22111'}), confidence=0.46511627906976744, lift=5.265628333688927)])
# yes
# RelationRecord(items=frozenset({'22835', '22112'}), support=0.044975688816855756, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22835', '22112'}), confidence=0.044975688816855756, lift=1.0), OrderedStatistic(items_base=frozenset({'22112'}), items_add=frozenset({'22835'}), confidence=0.5162790697674419, lift=7.914141268236313), OrderedStatistic(items_base=frozenset({'22835'}), items_add=frozenset({'22112'}), confidence=0.6894409937888198, lift=7.914141268236313)])
# yes
# RelationRecord(items=frozenset({'22727', '22726'}), support=0.044975688816855756, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22726', '22727'}), confidence=0.044975688816855756, lift=1.0), OrderedStatistic(items_base=frozenset({'22726'}), items_add=frozenset({'22727'}), confidence=0.7161290322580646, lift=12.10552364118427), OrderedStatistic(items_base=frozenset({'22727'}), items_add=frozenset({'22726'}), confidence=0.7602739726027398, lift=12.105523641184268)])

# %% [markdown]
# RelationRecord(items=frozenset({'22086', '22910'}), support=0.058752025931928686, ordered_statistics=[
#
#   OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22086', '22910'}), confidence=0.058752025931928686, lift=1.0),
#
# OrderedStatistic(items_base=frozenset({'22086'}), items_add=frozenset({'22910'}), confidence=0.5197132616487455, lift=5.938205230319926),
#
#  OrderedStatistic(items_base=frozenset({'22910'}), items_add=frozenset({'22086'}), confidence=0.6712962962962963, lift=5.938205230319926)])

# %%
set(data_xmas[(data_xmas['StockCode']=='22086')]['Description'])
# Out:
# {"PAPER CHAIN KIT 50'S CHRISTMAS "}

# %%
set(data_xmas[(data_xmas['StockCode']=='22910')]['Description'])
# Out:
# {'PAPER CHAIN KIT VINTAGE CHRISTMAS'}

# %%
set(data_xmas[(data_xmas['StockCode']=='22835')]['Description'])
# Out:
# {'HOT WATER BOTTLE I AM SO POORLY'}

# %%
set(data_xmas[(data_xmas['StockCode']=='22112')]['Description'])
# Out:
# {'CHOCOLATE HOT WATER BOTTLE'}

# %%
set(data_xmas[(data_xmas['StockCode']=='22726')]['Description'])
# Out:
# {'ALARM CLOCK BAKELIKE GREEN'}

# %%
set(data_xmas[(data_xmas['StockCode']=='22727')]['Description'])
# Out:
# {'ALARM CLOCK BAKELIKE RED '}

# %%
set(data_xmas[(data_xmas['StockCode']=='84029E')]['Description'])
# Out:
# {'RED WOOLLY HOTTIE WHITE HEART.'}

# %%
data[data['Country'] == 'Unspecified']
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 152712    549687     20685                DOORMAT RED RETROSPOT         2
# 152713    549687     22691              DOORMAT WELCOME SUNRISE         2
# 152714    549687     48116           DOORMAT MULTICOLOUR STRIPE         2
# 152715    549687     21213          PACK OF 72 SKULL CAKE CASES        24
# 152716    549687     21977   PACK OF 60 PINK PAISLEY CAKE CASES        24
# ...          ...       ...                                  ...       ...
# 498778    578539     22560           TRADITIONAL MODELLING CLAY        24
# 498779    578539     23570     TRADITIONAL PICK UP STICKS GAME         12
# 498780    578539     23571        TRADITIONAL NAUGHTS & CROSSES        12
# 498781    578539     84992       72 SWEETHEART FAIRY CAKE CASES        24
# 498782    578539     23309  SET OF 60 I LOVE LONDON CAKE CASES         24
#
#              InvoiceDate  UnitPrice  CustomerID      Country
# 152712  04/11/2011 13:29       7.95     12363.0  Unspecified
# 152713  04/11/2011 13:29       7.95     12363.0  Unspecified
# 152714  04/11/2011 13:29       7.95     12363.0  Unspecified
# 152715  04/11/2011 13:29       0.55     12363.0  Unspecified
# 152716  04/11/2011 13:29       0.55     12363.0  Unspecified
# ...                  ...        ...         ...          ...
# 498778  11/24/2011 14:55       1.25         NaN  Unspecified
# 498779  11/24/2011 14:55       1.25         NaN  Unspecified
# 498780  11/24/2011 14:55       1.65         NaN  Unspecified
# 498781  11/24/2011 14:55       0.55         NaN  Unspecified
# 498782  11/24/2011 14:55       0.55         NaN  Unspecified
#
# [446 rows x 8 columns]

# %% [markdown]
# # Q3 ของช่วงเวลา ตรุษจีน ใน ทวีป Asia (15 jan - 15 feb)

# %%
data_cny_asia = data_dadate[data_dadate['CNY_Period'] & (data_dadate["Continent"] == "Asia") ]

# %%
data_cny_asia
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 69623    541975     22620          4 TRADITIONAL SPINNING TOPS        60
# 69624    541975    85183B  CHARLIE & LOLA WASTEPAPER BIN FLORA         6
# 69625    541975    85183A   CHARLIE & LOLA WASTEPAPER BIN BLUE         6
# 69626    541975     16236                 KITTY PENCIL ERASERS        28
# 69627    541975     21058               PARTY INVITES WOODLAND        12
# ...         ...       ...                                  ...       ...
# 89595    543911    47590B          PINK HAPPY BIRTHDAY BUNTING        12
# 89596    543911     22117     METAL SIGN HER DINNER IS SERVED         12
# 89597    543911     82567            AIRLINE LOUNGE,METAL SIGN        12
# 89598    543911     21910                  WAY OUT METAL SIGN         12
# 89599    543911     21911                   GARDEN METAL SIGN         12
#
#            InvoiceDate  UnitPrice  CustomerID               Country Continent  \
# 69623  1/24/2011 14:24       1.25         NaN             Hong Kong      Asia
# 69624  1/24/2011 14:24       3.75         NaN             Hong Kong      Asia
# 69625  1/24/2011 14:24       3.75         NaN             Hong Kong      Asia
# 69626  1/24/2011 14:24       0.21         NaN             Hong Kong      Asia
# 69627  1/24/2011 14:24       0.85         NaN             Hong Kong      Asia
# ...                ...        ...         ...                   ...       ...
# 89595  2/14/2011 12:46       5.45     17829.0  United Arab Emirates      Asia
# 89596  2/14/2011 12:46       2.95     17829.0  United Arab Emirates      Asia
# 89597  2/14/2011 12:46       2.10     17829.0  United Arab Emirates      Asia
# 89598  2/14/2011 12:46       1.65     17829.0  United Arab Emirates      Asia
# 89599  2/14/2011 12:46       1.65     17829.0  United Arab Emirates      Asia
#
#                 date_time  Xmask_NY_Period  CNY_Period  V_Period
# 69623 2011-01-24 14:24:00            False        True     False
# 69624 2011-01-24 14:24:00            False        True     False
# 69625 2011-01-24 14:24:00            False        True     False
# 69626 2011-01-24 14:24:00            False        True     False
# 69627 2011-01-24 14:24:00            False        True     False
# ...                   ...              ...         ...       ...
# 89595 2011-02-14 12:46:00            False        True      True
# 89596 2011-02-14 12:46:00            False        True      True
# 89597 2011-02-14 12:46:00            False        True      True
# 89598 2011-02-14 12:46:00            False        True      True
# 89599 2011-02-14 12:46:00            False        True      True
#
# [273 rows x 13 columns]

# %%
transactions_cny = data_cny_asia.groupby('InvoiceNo')['StockCode'].apply(list)

# %%
transactions_cny
# Out:
# InvoiceNo
# 541975    [22620, 85183B, 85183A, 16236, 21058, 21967, 2...
# 542102    [21519, 22697, 22699, 22343, 22344, 22345, 223...
# 542276    [82551, 21165, 82600, 21754, 21756, 82482, 824...
# 543179    [22407, 22406, 22405, 21745, 22496, 22495, 224...
# 543518    [22759, 22662, 22661, 21717, 22957, 22861, 222...
# 543911    [21485, 48138, 85150, 82552, 82551, 82583, 224...
# Name: StockCode, dtype: object

# %%
min_sup = 0.3

frequentItemsets = list(apriori(transactions_cny,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>=3:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'22202', '22203', '20682'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22202', '22203', '20682'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'20682'}), items_add=frozenset({'22202', '22203'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202'}), items_add=frozenset({'22203', '20682'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22203'}), items_add=frozenset({'22202', '20682'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202', '20682'}), items_add=frozenset({'22203'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22203', '20682'}), items_add=frozenset({'22202'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202', '22203'}), items_add=frozenset({'20682'}), confidence=1.0, lift=3.0)])
# yes
# RelationRecord(items=frozenset({'22202', '22551', '20682'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22202', '22551', '20682'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'20682'}), items_add=frozenset({'22202', '22551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202'}), items_add=frozenset({'22551', '20682'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22551'}), items_add=frozenset({'22202', '20682'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202', '20682'}), items_add=frozenset({'22551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22551', '20682'}), items_add=frozenset({'22202'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202', '22551'}), items_add=frozenset({'20682'}), confidence=1.0, lift=3.0)])
# yes
# RelationRecord(items=frozenset({'22203', '22551', '20682'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20682', '22203', '22551'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'20682'}), items_add=frozenset({'22203', '22551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22203'}), items_add=frozenset({'22551', '20682'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22551'}), items_add=frozenset({'22203', '20682'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22203', '20682'}), items_add=frozenset({'22551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22551', '20682'}), items_add=frozenset({'22203'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22203', '22551'}), items_add=frozenset({'20682'}), confidence=1.0, lift=3.0)])
# yes
# RelationRecord(items=frozenset({'21439', '20725', '21216'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'21439', '20725', '21216'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'20725'}), items_add=frozenset({'21439', '21216'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21216'}), items_add=frozenset({'21439', '20725'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21439'}), items_add=frozenset({'20725', '21216'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'20725', '21216'}), items_add=frozenset({'21439'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21439', '20725'}), items_add=frozenset({'21216'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21439', '21216'}), items_add=frozenset({'20725'}), confidence=1.0, lift=3.0)])
# yes
# RelationRecord(items=frozenset({'82551', '21165', '82552'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'82551', '21165', '82552'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'21165'}), items_add=frozenset({'82551', '82552'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82551'}), items_add=frozenset({'21165', '82552'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82552'}), items_add=frozenset({'82551', '21165'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82551', '21165'}), items_add=frozenset({'82552'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21165', '82552'}), items_add=frozenset({'82551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82551', '82552'}), items_add=frozenset({'21165'}), confidence=1.0, lift=3.0)])
# yes
# RelationRecord(items=frozenset({'82551', '85150', '21165'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'82551', '85150', '21165'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'21165'}), items_add=frozenset({'82551', '85150'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82551'}), items_add=frozenset({'85150', '21165'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150'}), items_add=frozenset({'82551', '21165'}), confidence=0.6666666666666666, lift=2.0), OrderedStatistic(items_base=frozenset({'82551', '21165'}), items_add=frozenset({'85150'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'85150', '21165'}), items_add=frozenset({'82551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82551', '85150'}), items_add=frozenset({'21165'}), confidence=1.0, lift=3.0)])
# yes
# RelationRecord(items=frozenset({'85150', '21165', '82552'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85150', '21165', '82552'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'21165'}), items_add=frozenset({'85150', '82552'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82552'}), items_add=frozenset({'85150', '21165'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150'}), items_add=frozenset({'21165', '82552'}), confidence=0.6666666666666666, lift=2.0), OrderedStatistic(items_base=frozenset({'21165', '82552'}), items_add=frozenset({'85150'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'85150', '21165'}), items_add=frozenset({'82552'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150', '82552'}), items_add=frozenset({'21165'}), confidence=1.0, lift=3.0)])
# yes
# RelationRecord(items=frozenset({'22957', '21756', '22960'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22957', '21756', '22960'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'21756'}), items_add=frozenset({'22957', '22960'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'21756', '22960'}), confidence=0.6666666666666666, lift=2.0), OrderedStatistic(items_base=frozenset({'22960'}), items_add=frozenset({'22957', '21756'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22957', '21756'}), items_add=frozenset({'22960'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21756', '22960'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'22957', '22960'}), items_add=frozenset({'21756'}), confidence=1.0, lift=3.0)])
# yes
# RelationRecord(items=frozenset({'85150', '22957', '21756'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85150', '22957', '21756'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'21756'}), items_add=frozenset({'85150', '22957'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'85150', '21756'}), confidence=0.6666666666666666, lift=2.0), OrderedStatistic(items_base=frozenset({'85150'}), items_add=frozenset({'22957', '21756'}), confidence=0.6666666666666666, lift=2.0), OrderedStatistic(items_base=frozenset({'22957', '21756'}), items_add=frozenset({'85150'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'85150', '21756'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'85150', '22957'}), items_add=frozenset({'21756'}), confidence=1.0, lift=3.0)])
# yes
# RelationRecord(items=frozenset({'85150', '21756', '22960'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85150', '21756', '22960'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'21756'}), items_add=frozenset({'85150', '22960'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22960'}), items_add=frozenset({'85150', '21756'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150'}), items_add=frozenset({'21756', '22960'}), confidence=0.6666666666666666, lift=2.0), OrderedStatistic(items_base=frozenset({'21756', '22960'}), items_add=frozenset({'85150'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'85150', '21756'}), items_add=frozenset({'22960'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150', '22960'}), items_add=frozenset({'21756'}), confidence=1.0, lift=3.0)])
# yes
# RelationRecord(items=frozenset({'22202', '22203', '22551'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22202', '22203', '22551'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'22202'}), items_add=frozenset({'22203', '22551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22203'}), items_add=frozenset({'22202', '22551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22551'}), items_add=frozenset({'22202', '22203'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202', '22203'}), items_add=frozenset({'22551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202', '22551'}), items_add=frozenset({'22203'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22203', '22551'}), items_add=frozenset({'22202'}), confidence=1.0, lift=3.0)])
# yes
# RelationRecord(items=frozenset({'85150', '48138', '22413'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'48138', '85150', '22413'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'22413'}), items_add=frozenset({'48138', '85150'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'48138'}), items_add=frozenset({'85150', '22413'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150'}), items_add=frozenset({'48138', '22413'}), confidence=0.6666666666666666, lift=2.0), OrderedStatistic(items_base=frozenset({'48138', '22413'}), items_add=frozenset({'85150'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'85150', '22413'}), items_add=frozenset({'48138'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150', '48138'}), items_add=frozenset({'22413'}), confidence=1.0, lift=3.0)])
# yes
# RelationRecord(items=frozenset({'85150', '22957', '22960'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85150', '22957', '22960'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'85150', '22960'}), confidence=0.6666666666666666, lift=2.0), OrderedStatistic(items_base=frozenset({'22960'}), items_add=frozenset({'85150', '22957'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150'}), items_add=frozenset({'22957', '22960'}), confidence=0.6666666666666666, lift=2.0), OrderedStatistic(items_base=frozenset({'22957', '22960'}), items_add=frozenset({'85150'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'85150', '22957'}), items_add=frozenset({'22960'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150', '22960'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0)])
# yes
# RelationRecord(items=frozenset({'82551', '85150', '82552'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'82551', '85150', '82552'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'82551'}), items_add=frozenset({'85150', '82552'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82552'}), items_add=frozenset({'82551', '85150'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150'}), items_add=frozenset({'82551', '82552'}), confidence=0.6666666666666666, lift=2.0), OrderedStatistic(items_base=frozenset({'82551', '82552'}), items_add=frozenset({'85150'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'82551', '85150'}), items_add=frozenset({'82552'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150', '82552'}), items_add=frozenset({'82551'}), confidence=1.0, lift=3.0)])
# yes
# RelationRecord(items=frozenset({'22202', '22203', '22551', '20682'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22202', '22203', '22551', '20682'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'20682'}), items_add=frozenset({'22202', '22203', '22551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202'}), items_add=frozenset({'20682', '22203', '22551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22203'}), items_add=frozenset({'22202', '22551', '20682'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22551'}), items_add=frozenset({'22202', '22203', '20682'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202', '20682'}), items_add=frozenset({'22203', '22551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22203', '20682'}), items_add=frozenset({'22202', '22551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22551', '20682'}), items_add=frozenset({'22202', '22203'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202', '22203'}), items_add=frozenset({'22551', '20682'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202', '22551'}), items_add=frozenset({'22203', '20682'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22203', '22551'}), items_add=frozenset({'22202', '20682'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202', '22203', '20682'}), items_add=frozenset({'22551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202', '22551', '20682'}), items_add=frozenset({'22203'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22203', '22551', '20682'}), items_add=frozenset({'22202'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22202', '22203', '22551'}), items_add=frozenset({'20682'}), confidence=1.0, lift=3.0)])
# yes
# RelationRecord(items=frozenset({'82551', '85150', '21165', '82552'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'82551', '85150', '21165', '82552'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'21165'}), items_add=frozenset({'82551', '85150', '82552'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82551'}), items_add=frozenset({'85150', '21165', '82552'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82552'}), items_add=frozenset({'82551', '85150', '21165'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150'}), items_add=frozenset({'82551', '21165', '82552'}), confidence=0.6666666666666666, lift=2.0), OrderedStatistic(items_base=frozenset({'82551', '21165'}), items_add=frozenset({'85150', '82552'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21165', '82552'}), items_add=frozenset({'82551', '85150'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150', '21165'}), items_add=frozenset({'82551', '82552'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82551', '82552'}), items_add=frozenset({'85150', '21165'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82551', '85150'}), items_add=frozenset({'21165', '82552'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150', '82552'}), items_add=frozenset({'82551', '21165'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82551', '21165', '82552'}), items_add=frozenset({'85150'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'82551', '85150', '21165'}), items_add=frozenset({'82552'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150', '21165', '82552'}), items_add=frozenset({'82551'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'82551', '85150', '82552'}), items_add=frozenset({'21165'}), confidence=1.0, lift=3.0)])
# yes
# RelationRecord(items=frozenset({'85150', '22957', '21756', '22960'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85150', '22957', '21756', '22960'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'21756'}), items_add=frozenset({'85150', '22957', '22960'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22957'}), items_add=frozenset({'85150', '21756', '22960'}), confidence=0.6666666666666666, lift=2.0), OrderedStatistic(items_base=frozenset({'22960'}), items_add=frozenset({'85150', '22957', '21756'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150'}), items_add=frozenset({'22957', '21756', '22960'}), confidence=0.6666666666666666, lift=2.0), OrderedStatistic(items_base=frozenset({'22957', '21756'}), items_add=frozenset({'85150', '22960'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'21756', '22960'}), items_add=frozenset({'85150', '22957'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150', '21756'}), items_add=frozenset({'22957', '22960'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22957', '22960'}), items_add=frozenset({'85150', '21756'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150', '22957'}), items_add=frozenset({'21756', '22960'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150', '22960'}), items_add=frozenset({'22957', '21756'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'22957', '21756', '22960'}), items_add=frozenset({'85150'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'85150', '22957', '21756'}), items_add=frozenset({'22960'}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({'85150', '21756', '22960'}), items_add=frozenset({'22957'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'85150', '22957', '22960'}), items_add=frozenset({'21756'}), confidence=1.0, lift=3.0)])

# %% [markdown]
# # Q4 ช่วงเวลา Christmas & New years ในทวีป Europe (1 Dec - 31 Dec)

# %%
data_xmas_eu = data_dadate[data_dadate['Xmask_NY_Period'] & (data_dadate["Continent"]=="Europe")]

# %%
data_xmas_eu
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 0       12/01/2010 08:26       2.55     17850.0  United Kingdom    Europe
# 1       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 2       12/01/2010 08:26       2.75     17850.0  United Kingdom    Europe
# 3       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# 4       12/01/2010 08:26       3.39     17850.0  United Kingdom    Europe
# ...                  ...        ...         ...             ...       ...
# 541904  12/09/2011 12:50       0.85     12680.0          France    Europe
# 541905  12/09/2011 12:50       2.10     12680.0          France    Europe
# 541906  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541907  12/09/2011 12:50       4.15     12680.0          France    Europe
# 541908  12/09/2011 12:50       4.95     12680.0          France    Europe
#
#                  date_time  Xmask_NY_Period  CNY_Period  V_Period
# 0      2010-12-01 08:26:00             True       False     False
# 1      2010-12-01 08:26:00             True       False     False
# 2      2010-12-01 08:26:00             True       False     False
# 3      2010-12-01 08:26:00             True       False     False
# 4      2010-12-01 08:26:00             True       False     False
# ...                    ...              ...         ...       ...
# 541904 2011-12-09 12:50:00             True       False     False
# 541905 2011-12-09 12:50:00             True       False     False
# 541906 2011-12-09 12:50:00             True       False     False
# 541907 2011-12-09 12:50:00             True       False     False
# 541908 2011-12-09 12:50:00             True       False     False
#
# [66688 rows x 13 columns]

# %%
transactions_xmas_eu = data_xmas_eu.groupby('InvoiceNo')['StockCode'].apply(list)

# %%
min_sup = 0.04

frequentItemsets = list(apriori(transactions_xmas_eu,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'22086', '22910'}), support=0.05896705978039853, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22086', '22910'}), confidence=0.05896705978039853, lift=1.0), OrderedStatistic(items_base=frozenset({'22086'}), items_add=frozenset({'22910'}), confidence=0.5197132616487454, lift=5.91655051108456), OrderedStatistic(items_base=frozenset({'22910'}), items_add=frozenset({'22086'}), confidence=0.6712962962962963, lift=5.916550511084561)])
# yes
# RelationRecord(items=frozenset({'22111', '22112'}), support=0.040666937779585195, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22111', '22112'}), confidence=0.040666937779585195, lift=1.0), OrderedStatistic(items_base=frozenset({'22111'}), items_add=frozenset({'22112'}), confidence=0.4587155963302752, lift=5.2464262854704495), OrderedStatistic(items_base=frozenset({'22112'}), items_add=frozenset({'22111'}), confidence=0.46511627906976744, lift=5.2464262854704495)])
# yes
# RelationRecord(items=frozenset({'22835', '22112'}), support=0.04514030093533957, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22835', '22112'}), confidence=0.04514030093533957, lift=1.0), OrderedStatistic(items_base=frozenset({'22112'}), items_add=frozenset({'22835'}), confidence=0.5162790697674419, lift=7.885280947566083), OrderedStatistic(items_base=frozenset({'22835'}), items_add=frozenset({'22112'}), confidence=0.6894409937888198, lift=7.885280947566084)])
# yes
# RelationRecord(items=frozenset({'22727', '22726'}), support=0.044733631557543715, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22726', '22727'}), confidence=0.044733631557543715, lift=1.0), OrderedStatistic(items_base=frozenset({'22726'}), items_add=frozenset({'22727'}), confidence=0.7142857142857143, lift=12.113300492610838), OrderedStatistic(items_base=frozenset({'22727'}), items_add=frozenset({'22726'}), confidence=0.7586206896551724, lift=12.113300492610836)])

# %% [markdown]
# # Q5 ของวันวาเลนไทน์

# %%
data_v = data_dadate[data_dadate['V_Period']]

# %%
data_v
# Out:
#       InvoiceNo StockCode                         Description  Quantity  \
# 88847    543821     22926      IVORY GIANT GARDEN THERMOMETER         2
# 88848    543821     22928     YELLOW GIANT GARDEN THERMOMETER         2
# 88849    543821     22925       BLUE GIANT GARDEN THERMOMETER         2
# 88850    543821     85175               CACTI T-LIGHT CANDLES        16
# 88851    543821     22456     NATURAL SLATE CHALKBOARD LARGE          3
# ...         ...       ...                                 ...       ...
# 89949    543979     22196        SMALL HEART MEASURING SPOONS         1
# 89950    543979     21889              WOODEN BOX OF DOMINOES         1
# 89951    543979     85176          SEWING SUSAN 21 NEEDLE SET         1
# 89952    543979     37446  MINI CAKE STAND WITH HANGING CAKES         1
# 89953    543979     21657     MILK BOTTLE WITH GLASS STOPPER          1
#
#            InvoiceDate  UnitPrice  CustomerID         Country Continent  \
# 88847   2/14/2011 9:24       5.95     17667.0  United Kingdom    Europe
# 88848   2/14/2011 9:24       5.95     17667.0  United Kingdom    Europe
# 88849   2/14/2011 9:24       5.95     17667.0  United Kingdom    Europe
# 88850   2/14/2011 9:24       0.42     17667.0  United Kingdom    Europe
# 88851   2/14/2011 9:24       4.95     17667.0  United Kingdom    Europe
# ...                ...        ...         ...             ...       ...
# 89949  2/14/2011 15:43       0.85     14606.0  United Kingdom    Europe
# 89950  2/14/2011 15:43       1.25     14606.0  United Kingdom    Europe
# 89951  2/14/2011 15:43       0.85     14606.0  United Kingdom    Europe
# 89952  2/14/2011 15:43       1.45     14606.0  United Kingdom    Europe
# 89953  2/14/2011 15:43       6.95     14606.0  United Kingdom    Europe
#
#                 date_time  Xmask_NY_Period  CNY_Period  V_Period
# 88847 2011-02-14 09:24:00            False        True      True
# 88848 2011-02-14 09:24:00            False        True      True
# 88849 2011-02-14 09:24:00            False        True      True
# 88850 2011-02-14 09:24:00            False        True      True
# 88851 2011-02-14 09:24:00            False        True      True
# ...                   ...              ...         ...       ...
# 89949 2011-02-14 15:43:00            False        True      True
# 89950 2011-02-14 15:43:00            False        True      True
# 89951 2011-02-14 15:43:00            False        True      True
# 89952 2011-02-14 15:43:00            False        True      True
# 89953 2011-02-14 15:43:00            False        True      True
#
# [1087 rows x 13 columns]

# %%
transactions_v = data_v.groupby('InvoiceNo')['StockCode'].apply(list)
transactions_v
# Out:
# InvoiceNo
# 543821    [22926, 22928, 22925, 85175, 22456, 22854, 227...
# 543822    [22139, 20973, 22585, 22960, 84380, 84378, 229...
# 543823                         [22138, 21658, 22567, 20914]
# 543824    [22745, 22746, 20971, 20972, 16225, 22748, 227...
# 543825    [22926, 22782, 22411, 20914, 22381, 20681, 22690]
# 543826    [90104, 90146, 90175A, 90181B, 90214J, 90214S,...
# 543828    [22723, 22722, 22720, 22899, 22567, 84987, 228...
# 543829    [21238, 21239, 21240, 84997B, 84997D, 84997C, ...
# 543831    [84519A, 20711, 20713, 85099F, 22385, 21929, 2...
# 543832    [84879, 22077, 22855, 21899, 21900, 21901, 219...
# 543833    [22788, 22957, 21621, 22722, 22384, 21791, 217...
# 543836    [84987, 84991, 84988, 84992, 84378, 22965, 229...
# 543839                               [22207, 21731, 47590A]
# 543842                                              [22693]
# 543852    [22355, 21931, 22356, 85123A, 85175, 82484, 82...
# 543899    [C2, 21340, 21792, 22503, 15056N, 22630, 22983...
# 543900    [22355, 20719, 20723, 17003, 22331, 22385, 845...
# 543901           [21257, 22509, 22968, 20969, 22447, 22587]
# 543907    [84879, 22374, 22470, 22195, 22383, 47578A, 84...
# 543908                               [47590B, 21380, 22090]
# 543909    [16238, 20751, 21912, 21914, 21915, 21935, 219...
# 543910    [84978, 22595, 22197, 22469, 22470, 21523, 226...
# 543911    [21485, 48138, 85150, 82552, 82551, 82583, 224...
# 543912                  [21527, 21524, 20750, 21868, 37370]
# 543913    [21832, 82583, 21175, 21174, 21166, 82600, 825...
# 543914    [84356, 21221, 21681, 21682, 16237, 22491, 207...
# 543915    [10135, 47504K, 84509G, 84817, 84826, 85034C, ...
# 543916    [21034, 85099B, 22411, 85099C, 22386, 21928, 2...
# 543919    [20728, 84077, 22147, 22383, 22382, 20727, 227...
# 543920                                              [22171]
# 543921    [21613, 85173, 85206A, 22021, 21454, 22286, 35...
# 543922                                             [47570B]
# 543923    [22933, 22937, 22930, 22931, 22934, 22697, 226...
# 543924    [20785, 82551, 21380, 21175, 21174, 21179, 219...
# 543934    [21790, 22380, 22381, 22858, 21156, 21935, 227...
# 543935    [22607, 22605, 22698, 22301, 21621, 21137, 22041]
# 543973    [84755, 21688, 85062, 21695, 20668, 21340, 214...
# 543975    [84406B, 22926, 21870, 21874, 21713, 21714, 22...
# 543976                         [84879, 22423, 21422, 21421]
# 543977    [22384, 21211, 21210, 82551, 22457, 21623, 207...
# 543978    [22985, 22045, 23233, 23232, 23231, 85175, 223...
# 543979    [22072, 84988, 22382, 21931, 22380, 72760B, 22...
# Name: StockCode, dtype: object

# %%
min_sup = 0.1

frequentItemsets = list(apriori(transactions_v,min_support = min_sup))
for i in frequentItemsets:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'22720', '22722'}), support=0.11904761904761904, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22720', '22722'}), confidence=0.11904761904761904, lift=1.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'22722'}), confidence=0.7142857142857143, lift=5.0), OrderedStatistic(items_base=frozenset({'22722'}), items_add=frozenset({'22720'}), confidence=0.8333333333333334, lift=5.000000000000001)])
# yes
# RelationRecord(items=frozenset({'22720', '22969'}), support=0.11904761904761904, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22720', '22969'}), confidence=0.11904761904761904, lift=1.0), OrderedStatistic(items_base=frozenset({'22720'}), items_add=frozenset({'22969'}), confidence=0.7142857142857143, lift=6.000000000000001), OrderedStatistic(items_base=frozenset({'22969'}), items_add=frozenset({'22720'}), confidence=1.0, lift=6.0)])
